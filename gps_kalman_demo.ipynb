# %% [markdown]
# # GPS Kalman Filter Demo
# This notebook runs the simulation from `gps_kalman.py`. Run the cell below to see the Kalman filter output.

# %%
from gps_kalman import run_simulation

# %%
run_simulation()
